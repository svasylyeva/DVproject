# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pandas_profiling import ProfileReport
import time
from matplotlib import pyplot
import seaborn as sns
from sklearn import preprocessing

# %%
# path from github
#path_artworks = 'https://raw.githubusercontent.com/Beatriz-GFPereira/DV_Project/datasets/Artwork.csv'

# %%
data = pd.read_csv('Artworks.csv')

# %%
data.head()
# Out:
#                                                Title  \
# 0  Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1  City of Music, National Superior Conservatory ...
# 2  Villa near Vienna Project, Outside Vienna, Aus...
# 3  The Manhattan Transcripts Project, New York, N...
# 4  Villa, project, outside Vienna, Austria, Exter...
#
#                      Artist ConstituentID  \
# 0               Otto Wagner          6210
# 1  Christian de Portzamparc          7470
# 2                Emil Hoppe          7605
# 3           Bernard Tschumi          7056
# 4                Emil Hoppe          7605
#
#                                    ArtistBio Nationality BeginDate EndDate  \
# 0                      (Austrian, 1841–1918)  (Austrian)    (1841)  (1918)
# 1                        (French, born 1944)    (French)    (1944)     (0)
# 2                      (Austrian, 1876–1957)  (Austrian)    (1876)  (1957)
# 3  (French and Swiss, born Switzerland 1944)          ()    (1944)     (0)
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138151 entries, 0 to 138150
# Data columns (total 29 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Title               138112 non-null  object
#  1   Artist              136868 non-null  object
#  2   ConstituentID       136868 non-null  object
#  3   ArtistBio           132226 non-null  object
#  4   Nationality         136868 non-null  object
#  5   BeginDate           136868 non-null  object
#  6   EndDate             136868 non-null  object
#  7   Gender              136868 non-null  object
#  8   Date                135949 non-null  object
#  9   Medium              128450 non-null  object
#  10  Dimensions          128397 non-null  object
#  11  CreditLine          135714 non-null  object
#  12  AccessionNumber     138151 non-null  object
#  13  Classification      138151 non-null  object
#  14  Department          138151 non-null  object
# ...

# %%
data=data[['Title', 'Artist', 'Nationality', 'Gender', 'Date','Classification', 'Department']]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138151 entries, 0 to 138150
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Title           138112 non-null  object
#  1   Artist          136868 non-null  object
#  2   Nationality     136868 non-null  object
#  3   Gender          136868 non-null  object
#  4   Date            135949 non-null  object
#  5   Classification  138151 non-null  object
#  6   Department      138151 non-null  object
# dtypes: object(7)
# memory usage: 7.4+ MB

# %%
data= data.dropna()

# %%
data = data[~data.Artist.str.contains(", ")]

# %%
data
# Out:
#                                                     Title  \
# 0       Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1       City of Music, National Superior Conservatory ...
# 2       Villa near Vienna Project, Outside Vienna, Aus...
# 3       The Manhattan Transcripts Project, New York, N...
# 4       Villa, project, outside Vienna, Austria, Exter...
# ...                                                   ...
# 138145                                 Silver Springs, FL
# 138147  Plate (folio 2 verso) from Muscheln und schirm...
# 138148  Plate (folio 6) from Muscheln und schirme (She...
# 138149  Plate (folio 12) from Muscheln und schirme (Sh...
# 138150  Plate (folio 16) from Muscheln und schirme (Sh...
#
#                           Artist Nationality    Gender           Date  \
# 0                    Otto Wagner  (Austrian)    (Male)           1896
# 1       Christian de Portzamparc    (French)    (Male)           1987
# ...

# %%
len(data.Artist.unique())
# Out:
# 10849

# %%
data = data.drop_duplicates()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102141 entries, 0 to 138150
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Title           102141 non-null  object
#  1   Artist          102141 non-null  object
#  2   Nationality     102141 non-null  object
#  3   Gender          102141 non-null  object
#  4   Date            102141 non-null  object
#  5   Classification  102141 non-null  object
#  6   Department      102141 non-null  object
# dtypes: object(7)
# memory usage: 6.2+ MB

# %%
data.head()
# Out:
#                                                Title  \
# 0  Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1  City of Music, National Superior Conservatory ...
# 2  Villa near Vienna Project, Outside Vienna, Aus...
# 3  The Manhattan Transcripts Project, New York, N...
# 4  Villa, project, outside Vienna, Austria, Exter...
#
#                      Artist Nationality  Gender  Date Classification  \
# 0               Otto Wagner  (Austrian)  (Male)  1896   Architecture
# 1  Christian de Portzamparc    (French)  (Male)  1987   Architecture
# 2                Emil Hoppe  (Austrian)  (Male)  1903   Architecture
# 3           Bernard Tschumi          ()  (Male)  1980   Architecture
# 4                Emil Hoppe  (Austrian)  (Male)  1903   Architecture
#
#               Department
# 0  Architecture & Design
# 1  Architecture & Design
# 2  Architecture & Design
# 3  Architecture & Design
# 4  Architecture & Design

# %%
def remove_punct(test_str, punc):
    for ele in test_str:  
        if ele in punc:  
            test_str = test_str.replace(ele, "") 
    return test_str

# %%
punc=['(',')']

# %%
data['Nationality'] = data['Nationality'].map(lambda word: remove_punct(word,punc))

# %%
data['Gender'] = data['Gender'].map(lambda word: remove_punct(word,punc))

# %%
data.replace('',np.nan,inplace=True)

# %%
data = data.dropna()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97679 entries, 0 to 138150
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Title           97679 non-null  object
#  1   Artist          97679 non-null  object
#  2   Nationality     97679 non-null  object
#  3   Gender          97679 non-null  object
#  4   Date            97679 non-null  object
#  5   Classification  97679 non-null  object
#  6   Department      97679 non-null  object
# dtypes: object(7)
# memory usage: 6.0+ MB

# %%
data.reset_index(inplace=True)
